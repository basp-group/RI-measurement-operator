# %%
# auto reload
# %load_ext autoreload
# %autoreload 2

from example_sim_measop import gen_measop
import argparse
from example_sim_ri_data import main
import torch
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
args_measop = argparse.Namespace()
args_measop.yaml_file = '/work/ec110/ec110/cc2040/git_repos/basp/RI-measurement-operator-forked/config/sim_measop.yaml'

# %%
measop, nWimag, data_dict = gen_measop(args_measop)
# Out:
# INFO: user-specified pixel size: 5.6282e-01 arcsec (i.e. super resolution factor: 1.500)

# %%
args_ri_data = argparse.Namespace()
args_ri_data.yaml_file = '/work/ec110/ec110/cc2040/git_repos/basp/RI-measurement-operator-forked/config/sim_ri_data.yaml'

# %%
main(args_ri_data)
# Out:
# INFO: user-specified pixel size: 5.6282e-01 arcsec (i.e. super resolution factor: 1.500)
# Generate model visibilities ..
# Generate noise (noise level commensurate of the target dynamic range)...
# INFO: random Gaussian noise with input SNR: 63.163 dB
# Simulate data...
# Get back-projected data...
# Done
